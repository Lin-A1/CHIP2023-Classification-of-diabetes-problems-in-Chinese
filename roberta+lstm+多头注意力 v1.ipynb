# %%
import torch
import pandas as pd
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import jieba
import re
from transformers import BertTokenizer, BertForSequenceClassification,BertModel
from torch.utils.data import DataLoader, TensorDataset

# 检查是否有可用的GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# 加载BERT模型和tokenizer，并将它们移动到GPU上
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = BertTokenizer.from_pretrained("model/roberta/tokenizer")
bert_model = BertModel.from_pretrained("model/roberta/model").to(device)

# 冻结BERT模型参数
for param in bert_model.parameters():
    param.requires_grad_(False)

# 解冻部分BERT模型参数
for param in bert_model.encoder.layer[-3:].parameters():
    param.requires_grad_(True)

# 创建一个自定义的带有注意力机制的双向LSTM模型
class LSTMWithAttention(nn.Module):
    def __init__(self, bert_model, lstm_hidden_dim, num_labels, num_attention_heads, attention_dim, dropout_prob=0.2):
        super(LSTMWithAttention, self).__init__()
        self.bert_model = bert_model
        self.lstm_hidden_dim = lstm_hidden_dim
        self.num_labels = num_labels
        self.num_attention_heads = num_attention_heads
        self.attention_dim = attention_dim

        # LSTM层
        self.lstm = nn.LSTM(input_size=bert_model.config.hidden_size,
                            hidden_size=lstm_hidden_dim,
                            num_layers=4,
                            batch_first=True,
                            dropout=dropout_prob,
                            bidirectional=True)
        self.dropout = nn.Dropout(dropout_prob)

        # 多头自注意力层
        self.attention_layer = nn.MultiheadAttention(attention_dim,
                                                     num_attention_heads,
                                                     dropout=dropout_prob,
                                                     kdim=attention_dim,
                                                     vdim=attention_dim)

        # 全连接层进行分类
        self.fc = nn.Linear(lstm_hidden_dim * 2, num_labels)

    def forward(self, input_ids, attention_mask):
        # 使用BERT提取特征
        with torch.no_grad():  # 在BERT模型中不计算梯度
            outputs = self.bert_model(input_ids, attention_mask=attention_mask)
            bert_hidden_states = outputs.last_hidden_state

        # 将BERT的输出传递给LSTM
        lstm_output, _ = self.lstm(bert_hidden_states)
        lstm_output = self.dropout(lstm_output)

        # attention_dim 
        attention_output, _ = self.attention_layer(lstm_output.permute(1, 0, 2),
                                                   lstm_output.permute(1, 0, 2),
                                                   lstm_output.permute(1, 0, 2))
        attention_output = attention_output.permute(1, 0, 2)

        # 获取最后一个时间步的输出
        last_lstm_output = attention_output[:, -1, :]

        # 使用全连接层进行分类
        logits = self.fc(last_lstm_output)
        return logits

# 定义模型参数
lstm_hidden_dim = 256
num_labels = 6
num_attention_heads = 4  
attention_dim = lstm_hidden_dim*2  
dropout_prob = 0.1

# 创建BERT+LSTM模型带有注意力机制
model = LSTMWithAttention(bert_model, lstm_hidden_dim, num_labels, num_attention_heads, attention_dim, dropout_prob).to(device)

# %%
# 数据预处理
MAX_LEN = 64

def preprocess_data(df, tokenizer, max_len):
    input_ids = []
    attention_masks = []
    labels = []

    for index, row in df.iterrows():
        text = row[0]
        label = row[1]

        inputs = tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=max_len,
            padding='max_length',
            truncation=True,
            return_tensors='pt'
        )

        input_ids.append(inputs['input_ids'])
        attention_masks.append(inputs['attention_mask'])
        labels.append(label)

    input_ids = torch.cat(input_ids, dim=0).to(device)
    attention_masks = torch.cat(attention_masks, dim=0).to(device)
    labels = torch.tensor(labels, dtype=torch.long).to(device)

    return input_ids, attention_masks, labels

# %%
# 准备训练数据和验证数据
train_df = pd.read_table('input/train.txt',header=None)
dev_df = pd.read_table('input/dev.txt',header=None)

# %%
# def clean_text(text):
#     # 去除特殊字符、符号和数字
#     cleaned_text = re.sub(r'[^\u4e00-\u9fa5a-zA-Z\s]', '', text)
#     return cleaned_text

# train_df[0] = train_df[0].map(clean_text)
# dev_df[0] = dev_df[0].map(clean_text)

# %%
train_input_ids, train_attention_masks, train_labels = preprocess_data(train_df, tokenizer, MAX_LEN)
dev_input_ids, dev_attention_masks, dev_labels = preprocess_data(dev_df, tokenizer, MAX_LEN)

# 创建TensorDataset和DataLoader
train_dataset = TensorDataset(train_input_ids, train_attention_masks, train_labels)
dev_dataset = TensorDataset(dev_input_ids, dev_attention_masks, dev_labels)

train_batch_size = 128
dev_batch_size = 64

train_dataloader = DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True)
dev_dataloader = DataLoader(dev_dataset, batch_size=dev_batch_size)

# %%
# 定义优化器和损失函数
optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5)
loss_fn = torch.nn.CrossEntropyLoss()

# 训练模型
num_epochs = 200

for epoch in range(num_epochs):
    model.train()
    total_loss = 0

    for batch in train_dataloader:
        input_ids, attention_mask, labels = batch
        optimizer.zero_grad()

        # 前向传播
        logits = model(input_ids, attention_mask=attention_mask)
        
        # 计算交叉熵损失
        loss = loss_fn(logits, labels)
        
        # 反向传播和参数更新
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    avg_loss = total_loss / len(train_dataloader)
    print(f"Epoch {epoch + 1}/{num_epochs}, Average Loss: {avg_loss:.4f}",end='\t')

    # 在验证集上评估模型性能
    model.eval()
    val_preds = []
    val_labels = []

    for batch in dev_dataloader:
        input_ids, attention_mask, labels = batch
        with torch.no_grad():
            logits = model(input_ids, attention_mask=attention_mask)
        
        # 计算预测
        val_preds.extend(logits.argmax(dim=1).tolist())
        val_labels.extend(labels.tolist())

    
    correct_predictions = [1 if p == t else 0 for p, t in zip(val_preds, val_labels)]
    accuracy = sum(correct_predictions) / len(correct_predictions)
    print(f'Test_Accuracy: {accuracy * 100:.2f}%')
# Out:
# Epoch 1/200, Average Loss: 1.7275	Test_Accuracy: 25.10%
# Epoch 2/200, Average Loss: 1.4644	Test_Accuracy: 55.40%
# Epoch 3/200, Average Loss: 1.1031	Test_Accuracy: 62.10%
# Epoch 4/200, Average Loss: 0.9061	Test_Accuracy: 65.60%
# Epoch 5/200, Average Loss: 0.8045	Test_Accuracy: 72.80%
# Epoch 6/200, Average Loss: 0.7303	Test_Accuracy: 75.30%
# Epoch 7/200, Average Loss: 0.6501	Test_Accuracy: 75.90%
# Epoch 8/200, Average Loss: 0.5744	Test_Accuracy: 79.10%
# Epoch 9/200, Average Loss: 0.5331	Test_Accuracy: 79.70%
# Epoch 10/200, Average Loss: 0.4926	Test_Accuracy: 80.50%
# Epoch 11/200, Average Loss: 0.4650	Test_Accuracy: 80.60%
# Epoch 12/200, Average Loss: 0.4381	Test_Accuracy: 81.50%
# Epoch 13/200, Average Loss: 0.4190	Test_Accuracy: 81.70%
# Epoch 14/200, Average Loss: 0.4018	Test_Accuracy: 82.30%
# Epoch 15/200, Average Loss: 0.3996	Test_Accuracy: 81.90%
# Epoch 16/200, Average Loss: 0.3777	Test_Accuracy: 82.80%
# Epoch 17/200, Average Loss: 0.3622	Test_Accuracy: 81.30%
# Epoch 18/200, Average Loss: 0.3519	Test_Accuracy: 82.60%
# Epoch 19/200, Average Loss: 0.3408	Test_Accuracy: 82.20%
# Epoch 20/200, Average Loss: 0.3387	Test_Accuracy: 82.90%
# Epoch 21/200, Average Loss: 0.3259	Test_Accuracy: 83.00%
# Epoch 22/200, Average Loss: 0.3135	Test_Accuracy: 83.10%
# Epoch 23/200, Average Loss: 0.3032	Test_Accuracy: 83.20%
# Epoch 24/200, Average Loss: 0.2924	Test_Accuracy: 83.30%
# Epoch 25/200, Average Loss: 0.2894	Test_Accuracy: 83.30%
# Epoch 26/200, Average Loss: 0.2845	Test_Accuracy: 82.20%
# Epoch 27/200, Average Loss: 0.2783	Test_Accuracy: 84.50%
# Epoch 28/200, Average Loss: 0.2566	Test_Accuracy: 83.80%
# Epoch 29/200, Average Loss: 0.2524	Test_Accuracy: 83.00%
# Epoch 30/200, Average Loss: 0.2448	Test_Accuracy: 84.10%
# Epoch 31/200, Average Loss: 0.2388	Test_Accuracy: 83.60%
# Epoch 32/200, Average Loss: 0.2422	Test_Accuracy: 84.30%
# Epoch 33/200, Average Loss: 0.2367	Test_Accuracy: 84.60%
# Epoch 34/200, Average Loss: 0.2148	Test_Accuracy: 83.40%
# Epoch 35/200, Average Loss: 0.2192	Test_Accuracy: 83.90%
# Epoch 36/200, Average Loss: 0.2136	Test_Accuracy: 83.70%
# Epoch 37/200, Average Loss: 0.1968	Test_Accuracy: 83.70%
# Epoch 38/200, Average Loss: 0.1976	Test_Accuracy: 83.50%
# Epoch 39/200, Average Loss: 0.1840	Test_Accuracy: 83.40%
# Epoch 40/200, Average Loss: 0.1836	Test_Accuracy: 83.80%
# Epoch 41/200, Average Loss: 0.1887	Test_Accuracy: 84.70%
# Epoch 42/200, Average Loss: 0.1687	Test_Accuracy: 84.60%
# Epoch 43/200, Average Loss: 0.1698	Test_Accuracy: 84.20%
# Epoch 44/200, Average Loss: 0.1601	Test_Accuracy: 84.00%
# Epoch 45/200, Average Loss: 0.1664	Test_Accuracy: 83.00%
# Epoch 46/200, Average Loss: 0.1584	Test_Accuracy: 84.10%
# Epoch 47/200, Average Loss: 0.1533	Test_Accuracy: 84.40%
# Epoch 48/200, Average Loss: 0.1464	Test_Accuracy: 83.80%
# Epoch 49/200, Average Loss: 0.1464	Test_Accuracy: 84.20%
# Epoch 50/200, Average Loss: 0.1391	Test_Accuracy: 83.20%
# Epoch 51/200, Average Loss: 0.1369	Test_Accuracy: 83.40%
# Epoch 52/200, Average Loss: 0.1339	Test_Accuracy: 84.40%
# Epoch 53/200, Average Loss: 0.1395	Test_Accuracy: 83.20%
# Epoch 54/200, Average Loss: 0.1280	Test_Accuracy: 83.10%
# Epoch 55/200, Average Loss: 0.1226	Test_Accuracy: 83.70%
# Epoch 56/200, Average Loss: 0.1185	Test_Accuracy: 84.00%
# Epoch 57/200, Average Loss: 0.1243	Test_Accuracy: 83.80%
# Epoch 58/200, Average Loss: 0.1303	Test_Accuracy: 83.30%
# Epoch 59/200, Average Loss: 0.1193	Test_Accuracy: 83.70%
# Epoch 60/200, Average Loss: 0.1092	Test_Accuracy: 84.40%
# Epoch 61/200, Average Loss: 0.1087	Test_Accuracy: 83.50%
# Epoch 62/200, Average Loss: 0.1130	Test_Accuracy: 83.60%
# Epoch 63/200, Average Loss: 0.1059	Test_Accuracy: 84.00%
# Epoch 64/200, Average Loss: 0.0898	Test_Accuracy: 84.50%
# Epoch 65/200, Average Loss: 0.1001	Test_Accuracy: 83.10%
# Epoch 66/200, Average Loss: 0.0983	Test_Accuracy: 84.90%
# Epoch 67/200, Average Loss: 0.0993	Test_Accuracy: 82.00%
# Epoch 68/200, Average Loss: 0.1081	Test_Accuracy: 83.70%
# Epoch 69/200, Average Loss: 0.1104	Test_Accuracy: 83.20%
# Epoch 70/200, Average Loss: 0.0935	Test_Accuracy: 83.80%
# Epoch 71/200, Average Loss: 0.1009	Test_Accuracy: 83.60%
# Epoch 72/200, Average Loss: 0.0817	Test_Accuracy: 83.40%
# Epoch 73/200, Average Loss: 0.0862	Test_Accuracy: 83.60%
# Epoch 74/200, Average Loss: 0.0922	Test_Accuracy: 83.10%
# Epoch 75/200, Average Loss: 0.0806	Test_Accuracy: 84.60%
# Epoch 76/200, Average Loss: 0.0798	Test_Accuracy: 83.70%
# Epoch 77/200, Average Loss: 0.0869	Test_Accuracy: 84.30%
# Epoch 78/200, Average Loss: 0.0845	Test_Accuracy: 83.10%
# Epoch 79/200, Average Loss: 0.0698	Test_Accuracy: 83.80%
# Epoch 80/200, Average Loss: 0.0773	Test_Accuracy: 82.80%
# Epoch 81/200, Average Loss: 0.0769	Test_Accuracy: 82.60%
# Epoch 82/200, Average Loss: 0.0760	Test_Accuracy: 84.20%
# Epoch 83/200, Average Loss: 0.0650	Test_Accuracy: 83.60%
# Epoch 84/200, Average Loss: 0.0762	Test_Accuracy: 83.70%
# Epoch 85/200, Average Loss: 0.0706	Test_Accuracy: 83.90%
# Epoch 86/200, Average Loss: 0.0896	Test_Accuracy: 83.70%
# Epoch 87/200, Average Loss: 0.0793	Test_Accuracy: 84.10%
# Epoch 88/200, Average Loss: 0.0728	Test_Accuracy: 83.80%
# Epoch 89/200, Average Loss: 0.0566	Test_Accuracy: 83.40%
# Epoch 90/200, Average Loss: 0.0693	Test_Accuracy: 83.90%
# Epoch 91/200, Average Loss: 0.0604	Test_Accuracy: 83.80%
# Epoch 92/200, Average Loss: 0.0703	Test_Accuracy: 82.90%
# Epoch 93/200, Average Loss: 0.0603	Test_Accuracy: 83.00%
# Epoch 94/200, Average Loss: 0.0625	Test_Accuracy: 83.80%
# Epoch 95/200, Average Loss: 0.0655	Test_Accuracy: 83.40%
# Epoch 96/200, Average Loss: 0.0567	Test_Accuracy: 83.50%
# Epoch 97/200, Average Loss: 0.0658	Test_Accuracy: 83.70%
# Epoch 98/200, Average Loss: 0.0576	Test_Accuracy: 83.40%
# Epoch 99/200, Average Loss: 0.0643	Test_Accuracy: 83.30%
# Epoch 100/200, Average Loss: 0.0541	Test_Accuracy: 83.30%
# Epoch 101/200, Average Loss: 0.0563	Test_Accuracy: 83.90%
# Epoch 102/200, Average Loss: 0.0509	Test_Accuracy: 84.10%
# Epoch 103/200, Average Loss: 0.0568	Test_Accuracy: 83.70%
# Epoch 104/200, Average Loss: 0.0603	Test_Accuracy: 82.20%
# Epoch 105/200, Average Loss: 0.0626	Test_Accuracy: 84.00%
# Epoch 106/200, Average Loss: 0.0538	Test_Accuracy: 83.50%
# Epoch 107/200, Average Loss: 0.0503	Test_Accuracy: 84.10%
# Epoch 108/200, Average Loss: 0.0523	Test_Accuracy: 83.50%
# Epoch 109/200, Average Loss: 0.0484	Test_Accuracy: 83.20%
# Epoch 110/200, Average Loss: 0.0532	Test_Accuracy: 84.20%
# Epoch 111/200, Average Loss: 0.0429	Test_Accuracy: 84.00%
# Epoch 112/200, Average Loss: 0.0498	Test_Accuracy: 84.60%
# Epoch 113/200, Average Loss: 0.0519	Test_Accuracy: 83.60%
# Epoch 114/200, Average Loss: 0.0448	Test_Accuracy: 83.70%
# Epoch 115/200, Average Loss: 0.0541	Test_Accuracy: 82.80%
# Epoch 116/200, Average Loss: 0.0489	Test_Accuracy: 83.60%
# Epoch 117/200, Average Loss: 0.0579	Test_Accuracy: 83.50%
# Epoch 118/200, Average Loss: 0.0425	Test_Accuracy: 83.10%
# Epoch 119/200, Average Loss: 0.0417	Test_Accuracy: 83.40%
# Epoch 120/200, Average Loss: 0.0524	Test_Accuracy: 85.00%
# Epoch 121/200, Average Loss: 0.0429	Test_Accuracy: 82.80%
# Epoch 122/200, Average Loss: 0.0513	Test_Accuracy: 83.30%
# Epoch 123/200, Average Loss: 0.0566	Test_Accuracy: 83.90%
# Epoch 124/200, Average Loss: 0.0416	Test_Accuracy: 83.30%
# Epoch 125/200, Average Loss: 0.0365	Test_Accuracy: 83.60%
# Epoch 126/200, Average Loss: 0.0457	Test_Accuracy: 83.30%
# Epoch 127/200, Average Loss: 0.0392	Test_Accuracy: 83.70%
# Epoch 128/200, Average Loss: 0.0459	Test_Accuracy: 84.10%
# Epoch 129/200, Average Loss: 0.0454	Test_Accuracy: 84.20%
# Epoch 130/200, Average Loss: 0.0409	Test_Accuracy: 83.80%
# Epoch 131/200, Average Loss: 0.0387	Test_Accuracy: 82.10%
# Epoch 132/200, Average Loss: 0.0432	Test_Accuracy: 83.50%
# Epoch 133/200, Average Loss: 0.0395	Test_Accuracy: 83.20%
# Epoch 134/200, Average Loss: 0.0324	Test_Accuracy: 83.20%
# Epoch 135/200, Average Loss: 0.0434	Test_Accuracy: 84.30%
# Epoch 136/200, Average Loss: 0.0431	Test_Accuracy: 84.60%
# Epoch 137/200, Average Loss: 0.0427	Test_Accuracy: 84.30%
# Epoch 138/200, Average Loss: 0.0426	Test_Accuracy: 83.40%
# Epoch 139/200, Average Loss: 0.0397	Test_Accuracy: 84.30%
# Epoch 140/200, Average Loss: 0.0367	Test_Accuracy: 84.10%
# Epoch 141/200, Average Loss: 0.0339	Test_Accuracy: 84.10%
# Epoch 142/200, Average Loss: 0.0394	Test_Accuracy: 84.20%
# Epoch 143/200, Average Loss: 0.0406	Test_Accuracy: 84.90%
# Epoch 144/200, Average Loss: 0.0315	Test_Accuracy: 83.70%
# Epoch 145/200, Average Loss: 0.0388	Test_Accuracy: 83.30%
# Epoch 146/200, Average Loss: 0.0396	Test_Accuracy: 83.80%
# Epoch 147/200, Average Loss: 0.0447	Test_Accuracy: 83.90%
# Epoch 148/200, Average Loss: 0.0374	Test_Accuracy: 83.80%
# Epoch 149/200, Average Loss: 0.0325	Test_Accuracy: 83.10%
# Epoch 150/200, Average Loss: 0.0371	Test_Accuracy: 85.30%
# Epoch 151/200, Average Loss: 0.0343	Test_Accuracy: 84.70%
# Epoch 152/200, Average Loss: 0.0356	Test_Accuracy: 83.10%
# Epoch 153/200, Average Loss: 0.0306	Test_Accuracy: 84.20%
# Epoch 154/200, Average Loss: 0.0318	Test_Accuracy: 85.00%
# Epoch 155/200, Average Loss: 0.0287	Test_Accuracy: 84.10%
# Epoch 156/200, Average Loss: 0.0234	Test_Accuracy: 84.80%
# Epoch 157/200, Average Loss: 0.0311	Test_Accuracy: 84.10%
# Epoch 158/200, Average Loss: 0.0309	Test_Accuracy: 83.80%
# Epoch 159/200, Average Loss: 0.0340	Test_Accuracy: 84.90%
# Epoch 160/200, Average Loss: 0.0314	Test_Accuracy: 83.30%
# Epoch 161/200, Average Loss: 0.0202	Test_Accuracy: 84.90%
# Epoch 162/200, Average Loss: 0.0311	Test_Accuracy: 84.50%
# Epoch 163/200, Average Loss: 0.0387	Test_Accuracy: 83.20%
# Epoch 164/200, Average Loss: 0.0220	Test_Accuracy: 83.50%
# Epoch 165/200, Average Loss: 0.0317	Test_Accuracy: 83.00%
# Epoch 166/200, Average Loss: 0.0252	Test_Accuracy: 83.80%
# Epoch 167/200, Average Loss: 0.0296	Test_Accuracy: 84.40%
# Epoch 168/200, Average Loss: 0.0283	Test_Accuracy: 84.50%
# Epoch 169/200, Average Loss: 0.0344	Test_Accuracy: 82.60%
# Epoch 170/200, Average Loss: 0.0313	Test_Accuracy: 84.00%
# Epoch 171/200, Average Loss: 0.0240	Test_Accuracy: 84.60%
# Epoch 172/200, Average Loss: 0.0324	Test_Accuracy: 83.80%
# Epoch 173/200, Average Loss: 0.0232	Test_Accuracy: 84.90%
# Epoch 174/200, Average Loss: 0.0341	Test_Accuracy: 84.60%
# Epoch 175/200, Average Loss: 0.0302	Test_Accuracy: 84.70%
# Epoch 176/200, Average Loss: 0.0386	Test_Accuracy: 83.90%
# Epoch 177/200, Average Loss: 0.0348	Test_Accuracy: 84.00%
# Epoch 178/200, Average Loss: 0.0297	Test_Accuracy: 83.70%
# Epoch 179/200, Average Loss: 0.0314	Test_Accuracy: 83.60%
# Epoch 180/200, Average Loss: 0.0220	Test_Accuracy: 83.10%
# Epoch 181/200, Average Loss: 0.0247	Test_Accuracy: 84.60%
# Epoch 182/200, Average Loss: 0.0362	Test_Accuracy: 84.40%
# Epoch 183/200, Average Loss: 0.0236	Test_Accuracy: 84.20%
# Epoch 184/200, Average Loss: 0.0275	Test_Accuracy: 84.30%
# Epoch 185/200, Average Loss: 0.0294	Test_Accuracy: 84.00%
# Epoch 186/200, Average Loss: 0.0314	Test_Accuracy: 84.20%
# Epoch 187/200, Average Loss: 0.0289	Test_Accuracy: 83.80%
# Epoch 188/200, Average Loss: 0.0247	Test_Accuracy: 84.60%
# Epoch 189/200, Average Loss: 0.0258	Test_Accuracy: 84.40%
# Epoch 190/200, Average Loss: 0.0200	Test_Accuracy: 83.60%
# Epoch 191/200, Average Loss: 0.0195	Test_Accuracy: 83.80%
# Epoch 192/200, Average Loss: 0.0179	Test_Accuracy: 84.10%
# Epoch 193/200, Average Loss: 0.0170	Test_Accuracy: 84.90%
# Epoch 194/200, Average Loss: 0.0211	Test_Accuracy: 84.50%
# Epoch 195/200, Average Loss: 0.0354	Test_Accuracy: 84.60%
# Epoch 196/200, Average Loss: 0.0234	Test_Accuracy: 83.70%
# Epoch 197/200, Average Loss: 0.0217	Test_Accuracy: 84.20%
# Epoch 198/200, Average Loss: 0.0170	Test_Accuracy: 83.70%
# Epoch 199/200, Average Loss: 0.0239	Test_Accuracy: 83.10%
# Epoch 200/200, Average Loss: 0.0342	Test_Accuracy: 83.30%

# %%
test_df = pd.read_table('input/dev.txt',header=None)

# 数据预处理
test_input_ids, test_attention_masks, _ = preprocess_data(test_df, tokenizer, MAX_LEN)

# 创建 DataLoader
test_dataset = TensorDataset(test_input_ids, test_attention_masks)
test_batch_size = 64
test_dataloader = DataLoader(test_dataset, batch_size=test_batch_size)

# 将模型设置为评估模式
model.eval()

# 存储预测结果
predictions = []

# 遍历测试数据并进行预测
for batch in test_dataloader:
    input_ids, attention_mask = batch
    input_ids = input_ids.to(device)
    attention_mask = attention_mask.to(device)
    with torch.no_grad():
        # 前向传播
        logits = model(input_ids, attention_mask=attention_mask)
    
    # 计算预测
    predicted_labels = logits.argmax(dim=1).tolist()
    predictions.extend(predicted_labels)

# %%
true_labels = test_df[1]

# 计算准确度
correct_predictions = [1 if p == t else 0 for p, t in zip(predictions, true_labels)]
accuracy = sum(correct_predictions) / len(correct_predictions)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 83.30%
